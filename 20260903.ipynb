# %% [markdown]
# <a href="https://colab.research.google.com/github/26402-pixel/10702/blob/main/20260903.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('재밌는 프로그래밍')
print(3+7)
print('3+7')
print(10,20,30,'정보','프로그래밍')

# %%
print('한양과학기술고등학교','1학년','김시헌')
print(58/(178*178)*10000)
# Out:
# 한양과학기술고등학교 1학년 김시헌
# 18.30576947355132

# %%
print('현재 온도는 %d도 입니다.'%20)
# Out:
# 현재 온도는 20도 입니다.

# %%
print(f'현재 온도는 {20}도 입니다.')
# Out:
# 현재 온도는 20도 입니다.

# %%
a=20
b=50
print(f'현재 온도는 {a}도,습도는 {b}%입니다')
# Out:
# 현재 온도는 20도,습도는 50%입니다

# %%
c=90
d=3.141592
print(f'직각의 각도는 {c}도,원주율은 {d:0.2f}입니다.')
# Out:
# 직각의 각도는 90도,원주율은 3.14입니다.

# %%
print('동해 물과 \'백두산\'이')
print('동해 물과 "백두산"이')
print('마르고 닳도록')
print('하느님이 보우하사')
print('우리나라 만세')
print('무궁화 삼천리 화려강산')
print('대한사람,"대한"으로 길이 보전하세.')
print('2026','05','20',sep='-')
# Out:
# 동해 물과 '백두산'이
# 동해 물과 "백두산"이
# 마르고 닳도록
# 하느님이 보우하사
# 우리나라 만세
# 무궁화 삼천리 화려강산
# 대한사람,"대한"으로 길이 보전하세.
# 2026-05-20

# %%
print('품목\t가격\t개수\n사과\t2,000\t8\n바나나\t3,000\t5')
# Out:
# 품목	가격	개수
# 사과	2,000	8
# 바나나	3,000	5

# %%
a=int(input('학번을 입력하십시오'))
b=input('이름을 입력하십시오')
c=input('학과를 입력하십시오')
print('###################')213weds
ad
print('[한양과학기술고등학교 학생증]')
print(f'*학번:{a}')
print(f'*성명:{b}')
print(f'*소속:{c}')
print('위 사람은 본 학교의 학생임을 증명함.')
print('###################')
# Out:
# 학번을 입력하십시오312
# 이름을 입력하십시오
# 학과를 입력하십시오
# ###################
# [한양과학기술고등학교 학생증]
# *학번:312
# *성명:
# *소속:
# 위 사람은 본 학교의 학생임을 증명함.
# ###################

# %%
dlldd
