# %% [markdown]
# <a href="https://colab.research.google.com/github/26402-pixel/10702/blob/main/20260910.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a='hello'
b='world'
print(a+b)
print(a*3)
print(a<b)
print('h'in a)
print('wor'not in b)
# Out:
# helloworld
# hellohellohello
# True
# True
# False

# %%
a='hello python'
print(a[0])
print(a[6])
print(a[-1])
# Out:
# h
# p
# n

# %%
a='Hello Python'
print(a[0:5])
print(a[6:])
print(a[6:-4])
print(a[:5])
print(a[0:9:2])
# Out:
# Hello
# Python
# Py
# Hello
# HloPt

# %%
a=input('주민등록번호를 입력하세요.')
print(f'년도:{a[0:2]}')
print(f'월:{a[2:4]}')
print(f'일:{a[4:6]}')
# Out:
# 주민등록번호를 입력하세요.101218
# 년도:10
# 월:12
# 일:18

# %%
a=input('문자열을 입력하십시오')
b=a[::-1]
b.replace('a','3')
# Out:
# 문자열을 입력하십시오abcde
# 'edcb3'

# %%
\
