# %% [markdown]
# <a href="https://colab.research.google.com/github/26402-pixel/10702/blob/main/2_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('재밌는 프로그래밍')
print(3+7)
print('3+7')
print(10,20,30,'정보','프로그래밍')

# %%
print('한양과학기술고등학교','1학년','김시헌')
print(58/(178*178)*10000)
# Out:
# 한양과학기술고등학교 1학년 김시헌
# 18.30576947355132

# %%
print('현재 온도는 %d도 입니다.'%20)
# Out:
# 현재 온도는 20도 입니다.

# %%
print(f'현재 온도는 {20}도 입니다.')
# Out:
# 현재 온도는 20도 입니다.

# %%
a=20
b=50
print(f'현재 온도는 {a}도,습도는 {b}%입니다')
# Out:
# 현재 온도는 20도,습도는 50%입니다

# %%
c=90
d=3.141592
print(f'직각의 각도는 {c}도,원주율은 {d:0.2f}입니다.')
# Out:
# 직각의 각도는 90도,원주율은 3.14입니다.
