# %% [markdown]
# <a href="https://colab.research.google.com/github/26402-pixel/10702/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
redCount=int(input('빨간색 접시의 개수를 입력하세요.'))
yellowCount=int(input('노란색 접시의 개수를 입력입력하세요.'))
blueCount=int(input('파란색 접시의 개수를 입력하세요.'))
greenCount=int(input('초록색 접시의 개수를 입력하세요.'))
print('=====회전초밥 영수증=====')
print(f'접시\t단가\t개수\t합계\n빨간색 1,000\t{redCount}\t {redCount*1000}\n노란색 2,000\t{yellowCount}\t{yellowCount*2000}\n파란색3,000\t{blueCount}\t{blueCount*3000}\n초록색 4,000\t{greenCount}\t{greenCount*4000}\n합계\t'(redCount*1000)+(yellowCount*2000)+(blueCount*3000)+(greenCount*4000))
# Out:
# <>:6: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <>:6: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# 빨간색 접시의 개수를 입력하세요.1
# 노란색 접시의 개수를 입력입력하세요.3
# 파란색 접시의 개수를 입력하세요.4
# 초록색 접시의 개수를 입력하세요.1
# =====회전초밥 영수증=====
# /tmp/ipykernel_1107/795263193.py:6: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   print(f'접시\t단가\t개수\t합계\n빨간색 1,000\t{redCount}\t {redCount*1000}\n노란색 2,000\t{yellowCount}\t{yellowCount*2000}\n파란색3,000\t{blueCount}\t{blueCount*3000}\n초록색 4,000\t{greenCount}\t{greenCount*4000}\n합계\t'(redCount*1000)+(yellowCount*2000)+(blueCount*3000)+(greenCount*4000))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1107/795263193.py in <cell line: 0>()
#       4 greenCount=int(input('초록색 접시의 개수를 입력하세요.'))
#       5 print('=====회전초밥 영수증=====')
# ...
